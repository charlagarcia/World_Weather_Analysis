# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of 2000 random latitudes & longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high =180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy
import time
from datetime import datetime

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_weather_description})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | tubigan
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | los llanos de aridane
# Processing Record 6 of Set 1 | ust-nera
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | husavik
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | bambanglipuro
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | bonavista
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | sorong
# Processing Record 30 of Set 1 | qui nhon
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | vila franca do campo
# Processing Record 36 of Set 1 | cayenne
# Processing Record 37 of Set 1 | koga
# Processing Record 38 of Set 1 | barguzin
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | tessalit
# Processing Record 41 of Set 1 | svetlogorsk
# Processing Record 42 of Set 1 | havre-saint-pierre
# Processing Record 43 of Set 1 | platteville
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | lavrentiya
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | inhambane
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | uray
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | sale
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 2 | klyuchi
# Processing Record 15 of Set 2 | maceio
# Processing Record 16 of Set 2 | chicama
# Processing Record 17 of Set 2 | ouadda
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | elko
# Processing Record 23 of Set 2 | vammala
# Processing Record 24 of Set 2 | metehara
# City not found. Skipping...
# Processing Record 25 of Set 2 | praia da vitoria
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | kauswagan
# Processing Record 28 of Set 2 | brewster
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | juneau
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | north bend
# Processing Record 35 of Set 2 | westport
# Processing Record 36 of Set 2 | broome
# Processing Record 37 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 2 | faanui
# Processing Record 39 of Set 2 | tikamgarh
# Processing Record 40 of Set 2 | constitucion
# Processing Record 41 of Set 2 | tacna
# Processing Record 42 of Set 2 | krutinka
# Processing Record 43 of Set 2 | mari-turek
# Processing Record 44 of Set 2 | buarcos
# Processing Record 45 of Set 2 | kerouane
# Processing Record 46 of Set 2 | okhotsk
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | dali
# Processing Record 1 of Set 3 | takoradi
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | marsala
# Processing Record 9 of Set 3 | bontang
# Processing Record 10 of Set 3 | schoneiche
# Processing Record 11 of Set 3 | botwood
# Processing Record 12 of Set 3 | forio
# Processing Record 13 of Set 3 | morgan city
# Processing Record 14 of Set 3 | victoria
# Processing Record 15 of Set 3 | muyezerskiy
# Processing Record 16 of Set 3 | bilma
# Processing Record 17 of Set 3 | sheregesh
# Processing Record 18 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 19 of Set 3 | pareora
# Processing Record 20 of Set 3 | namatanai
# Processing Record 21 of Set 3 | ode
# Processing Record 22 of Set 3 | beloha
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | enshi
# Processing Record 25 of Set 3 | cockburn town
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | preobrazheniye
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | yuzhno-kurilsk
# Processing Record 30 of Set 3 | anadyr
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | akyab
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | walvis bay
# Processing Record 36 of Set 3 | dhidhdhoo
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | ixtapa
# Processing Record 39 of Set 3 | letterkenny
# Processing Record 40 of Set 3 | cuamba
# Processing Record 41 of Set 3 | nuuk
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | sinnamary
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | uyuni
# Processing Record 48 of Set 3 | shelburne
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | port shepstone
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | belyy yar
# Processing Record 4 of Set 4 | anandnagar
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | hwange
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | jumla
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | bulungu
# Processing Record 11 of Set 4 | osorno
# Processing Record 12 of Set 4 | trabzon
# Processing Record 13 of Set 4 | karratha
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | alice springs
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | gat
# Processing Record 18 of Set 4 | cape town
# Processing Record 19 of Set 4 | valparaiso
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | vredendal
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | erenhot
# Processing Record 26 of Set 4 | sabla
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | lima
# Processing Record 29 of Set 4 | miyako
# Processing Record 30 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | ormara
# Processing Record 33 of Set 4 | tambacounda
# Processing Record 34 of Set 4 | biltine
# Processing Record 35 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | ibra
# Processing Record 39 of Set 4 | kloulklubed
# Processing Record 40 of Set 4 | yucca valley
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | basoko
# Processing Record 43 of Set 4 | taitung
# Processing Record 44 of Set 4 | vila velha
# Processing Record 45 of Set 4 | hays
# Processing Record 46 of Set 4 | businga
# Processing Record 47 of Set 4 | bone
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | banda aceh
# Processing Record 50 of Set 4 | culebra
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | gizo
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | rabo de peixe
# Processing Record 6 of Set 5 | atraulia
# Processing Record 7 of Set 5 | north las vegas
# Processing Record 8 of Set 5 | arlit
# Processing Record 9 of Set 5 | lala
# Processing Record 10 of Set 5 | sandwick
# Processing Record 11 of Set 5 | pa sang
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | agirish
# Processing Record 15 of Set 5 | xilitla
# Processing Record 16 of Set 5 | orlik
# Processing Record 17 of Set 5 | muros
# Processing Record 18 of Set 5 | mindelo
# Processing Record 19 of Set 5 | warrington
# Processing Record 20 of Set 5 | uruguaiana
# Processing Record 21 of Set 5 | iowa city
# Processing Record 22 of Set 5 | poum
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | lazaro cardenas
# Processing Record 25 of Set 5 | inirida
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | camocim
# Processing Record 28 of Set 5 | sipe sipe
# Processing Record 29 of Set 5 | westlock
# Processing Record 30 of Set 5 | susanville
# Processing Record 31 of Set 5 | moranbah
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | general roca
# Processing Record 34 of Set 5 | sisimiut
# Processing Record 35 of Set 5 | campoverde
# Processing Record 36 of Set 5 | itarema
# Processing Record 37 of Set 5 | broken hill
# Processing Record 38 of Set 5 | bartica
# Processing Record 39 of Set 5 | maamba
# Processing Record 40 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 5 | salinas
# Processing Record 42 of Set 5 | murray bridge
# Processing Record 43 of Set 5 | lac du bonnet
# Processing Record 44 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 5 | kalabo
# Processing Record 46 of Set 5 | ghanzi
# Processing Record 47 of Set 5 | cape coast
# Processing Record 48 of Set 5 | te anau
# Processing Record 49 of Set 5 | bud
# Processing Record 50 of Set 5 | aitape
# Processing Record 1 of Set 6 | edmonton
# Processing Record 2 of Set 6 | moree
# Processing Record 3 of Set 6 | porecatu
# Processing Record 4 of Set 6 | fort walton beach
# Processing Record 5 of Set 6 | nikolskoye
# Processing Record 6 of Set 6 | kabo
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | santa cruz
# Processing Record 9 of Set 6 | doha
# Processing Record 10 of Set 6 | manakara
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | nouadhibou
# Processing Record 13 of Set 6 | agua verde
# Processing Record 14 of Set 6 | rakhya
# City not found. Skipping...
# Processing Record 15 of Set 6 | samoylovka
# Processing Record 16 of Set 6 | alekseyevsk
# Processing Record 17 of Set 6 | ponta do sol
# Processing Record 18 of Set 6 | pierre
# Processing Record 19 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 6 | afua
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | nehe
# Processing Record 24 of Set 6 | san matias
# Processing Record 25 of Set 6 | socorro
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | gunjur
# Processing Record 29 of Set 6 | barsovo
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | toba
# Processing Record 34 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 35 of Set 6 | alamogordo
# Processing Record 36 of Set 6 | salaga
# Processing Record 37 of Set 6 | bom jesus
# Processing Record 38 of Set 6 | nieuw nickerie
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | vaini
# Processing Record 41 of Set 6 | gambo
# Processing Record 42 of Set 6 | akdepe
# Processing Record 43 of Set 6 | baykalovo
# Processing Record 44 of Set 6 | male
# Processing Record 45 of Set 6 | magistralnyy
# Processing Record 46 of Set 6 | vanderhoof
# Processing Record 47 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 48 of Set 6 | mathbaria
# Processing Record 49 of Set 6 | tripoli
# Processing Record 50 of Set 6 | baherden
# Processing Record 1 of Set 7 | zheleznogorsk
# Processing Record 2 of Set 7 | teacapan
# Processing Record 3 of Set 7 | malmo
# Processing Record 4 of Set 7 | yulara
# Processing Record 5 of Set 7 | pahrump
# Processing Record 6 of Set 7 | ketchikan
# Processing Record 7 of Set 7 | bloemfontein
# Processing Record 8 of Set 7 | chernyshevskiy
# Processing Record 9 of Set 7 | pervomayskoye
# Processing Record 10 of Set 7 | mana
# Processing Record 11 of Set 7 | sumbe
# Processing Record 12 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 7 | matamoros
# Processing Record 14 of Set 7 | alofi
# Processing Record 15 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 7 | puebla
# Processing Record 17 of Set 7 | rocha
# Processing Record 18 of Set 7 | huaicheng
# Processing Record 19 of Set 7 | khatanga
# Processing Record 20 of Set 7 | catuday
# Processing Record 21 of Set 7 | cairns
# Processing Record 22 of Set 7 | igarka
# Processing Record 23 of Set 7 | svetlyy
# Processing Record 24 of Set 7 | palasa
# Processing Record 25 of Set 7 | pombas
# Processing Record 26 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 7 | christchurch
# Processing Record 28 of Set 7 | talnakh
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | udachnyy
# Processing Record 32 of Set 7 | macara
# Processing Record 33 of Set 7 | donskoye
# Processing Record 34 of Set 7 | datong
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | port hardy
# Processing Record 37 of Set 7 | kazanskaya
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | labuhan
# Processing Record 41 of Set 7 | kambove
# Processing Record 42 of Set 7 | klaksvik
# Processing Record 43 of Set 7 | akashi
# Processing Record 44 of Set 7 | novobirilyussy
# Processing Record 45 of Set 7 | prado
# Processing Record 46 of Set 7 | severnyy
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | ariguani
# Processing Record 49 of Set 7 | pangoa
# Processing Record 50 of Set 7 | ati
# Processing Record 1 of Set 8 | coihaique
# Processing Record 2 of Set 8 | mpika
# Processing Record 3 of Set 8 | bonthe
# Processing Record 4 of Set 8 | wangqing
# Processing Record 5 of Set 8 | putina
# Processing Record 6 of Set 8 | almaznyy
# Processing Record 7 of Set 8 | vikersund
# Processing Record 8 of Set 8 | bathsheba
# Processing Record 9 of Set 8 | taseyevo
# Processing Record 10 of Set 8 | arawa
# Processing Record 11 of Set 8 | port blair
# Processing Record 12 of Set 8 | mehamn
# Processing Record 13 of Set 8 | raahe
# Processing Record 14 of Set 8 | puerto maldonado
# Processing Record 15 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 8 | eyl
# Processing Record 17 of Set 8 | daura
# Processing Record 18 of Set 8 | asau
# Processing Record 19 of Set 8 | terbuny
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | hohhot
# Processing Record 22 of Set 8 | fort collins
# Processing Record 23 of Set 8 | kavaratti
# Processing Record 24 of Set 8 | mattru
# Processing Record 25 of Set 8 | bizhbulyak
# Processing Record 26 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 8 | kupang
# Processing Record 28 of Set 8 | burias
# Processing Record 29 of Set 8 | gravdal
# Processing Record 30 of Set 8 | sivas
# Processing Record 31 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 8 | somerset
# Processing Record 33 of Set 8 | novyy urengoy
# Processing Record 34 of Set 8 | finschhafen
# Processing Record 35 of Set 8 | baracoa
# Processing Record 36 of Set 8 | perth
# Processing Record 37 of Set 8 | vangaindrano
# Processing Record 38 of Set 8 | beringovskiy
# Processing Record 39 of Set 8 | dunda
# Processing Record 40 of Set 8 | saint george
# Processing Record 41 of Set 8 | qobustan
# Processing Record 42 of Set 8 | suntar
# Processing Record 43 of Set 8 | manggar
# Processing Record 44 of Set 8 | huanren
# Processing Record 45 of Set 8 | praia
# Processing Record 46 of Set 8 | labrea
# Processing Record 47 of Set 8 | havelock
# Processing Record 48 of Set 8 | luderitz
# Processing Record 49 of Set 8 | kahului
# Processing Record 50 of Set 8 | maniitsoq
# Processing Record 1 of Set 9 | panjakent
# Processing Record 2 of Set 9 | katangli
# Processing Record 3 of Set 9 | aklavik
# Processing Record 4 of Set 9 | lasa
# Processing Record 5 of Set 9 | lere
# Processing Record 6 of Set 9 | kibala
# Processing Record 7 of Set 9 | kavieng
# Processing Record 8 of Set 9 | heilbron
# Processing Record 9 of Set 9 | mirnyy
# Processing Record 10 of Set 9 | sosua
# Processing Record 11 of Set 9 | santa rosa
# Processing Record 12 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 9 | kingisepp
# Processing Record 14 of Set 9 | awjilah
# Processing Record 15 of Set 9 | ponta delgada
# Processing Record 16 of Set 9 | bonnyville
# Processing Record 17 of Set 9 | grand-lahou
# Processing Record 18 of Set 9 | hovd
# Processing Record 19 of Set 9 | zhigansk
# Processing Record 20 of Set 9 | kalemie
# Processing Record 21 of Set 9 | rosa zarate
# Processing Record 22 of Set 9 | montrose
# Processing Record 23 of Set 9 | kautokeino
# Processing Record 24 of Set 9 | florence
# Processing Record 25 of Set 9 | salinopolis
# Processing Record 26 of Set 9 | laguna
# Processing Record 27 of Set 9 | chhagalnaiya
# Processing Record 28 of Set 9 | rolla
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | albox
# Processing Record 31 of Set 9 | kismayo
# Processing Record 32 of Set 9 | antofagasta
# Processing Record 33 of Set 9 | villarrica
# Processing Record 34 of Set 9 | owando
# Processing Record 35 of Set 9 | porbandar
# Processing Record 36 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 9 | springbok
# Processing Record 38 of Set 9 | kalmunai
# Processing Record 39 of Set 9 | narsaq
# Processing Record 40 of Set 9 | vestmannaeyjar
# Processing Record 41 of Set 9 | alugan
# Processing Record 42 of Set 9 | canakkale
# Processing Record 43 of Set 9 | santa isabel do rio negro
# Processing Record 44 of Set 9 | mangrol
# Processing Record 45 of Set 9 | derzhavinsk
# Processing Record 46 of Set 9 | kyshtovka
# Processing Record 47 of Set 9 | kholm
# Processing Record 48 of Set 9 | sandy bay
# Processing Record 49 of Set 9 | mincivan
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | erzin
# Processing Record 3 of Set 10 | machinga
# Processing Record 4 of Set 10 | buala
# Processing Record 5 of Set 10 | jiangyou
# Processing Record 6 of Set 10 | samarai
# Processing Record 7 of Set 10 | kaspiyskiy
# Processing Record 8 of Set 10 | namibe
# Processing Record 9 of Set 10 | bose
# Processing Record 10 of Set 10 | chara
# Processing Record 11 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 10 | jalu
# Processing Record 13 of Set 10 | kungurtug
# Processing Record 14 of Set 10 | udala
# Processing Record 15 of Set 10 | semirara
# Processing Record 16 of Set 10 | renfrew
# Processing Record 17 of Set 10 | bara
# Processing Record 18 of Set 10 | ihosy
# Processing Record 19 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 10 | portalegre
# Processing Record 21 of Set 10 | mackay
# Processing Record 22 of Set 10 | starosubkhangulovo
# Processing Record 23 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 10 | kutum
# Processing Record 25 of Set 10 | coahuayana
# Processing Record 26 of Set 10 | kununurra
# Processing Record 27 of Set 10 | alihe
# Processing Record 28 of Set 10 | yelahanka
# Processing Record 29 of Set 10 | kumo
# Processing Record 30 of Set 10 | lusambo
# Processing Record 31 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 10 | ikwiriri
# Processing Record 34 of Set 10 | burica
# City not found. Skipping...
# Processing Record 35 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 10 | houston
# Processing Record 37 of Set 10 | claudio
# Processing Record 38 of Set 10 | half moon bay
# Processing Record 39 of Set 10 | sakakah
# Processing Record 40 of Set 10 | tucuman
# Processing Record 41 of Set 10 | gitarama
# Processing Record 42 of Set 10 | joshimath
# Processing Record 43 of Set 10 | soledade
# Processing Record 44 of Set 10 | krasnoselkup
# Processing Record 45 of Set 10 | dunedin
# Processing Record 46 of Set 10 | cannington
# Processing Record 47 of Set 10 | okmulgee
# Processing Record 48 of Set 10 | qostanay
# Processing Record 49 of Set 10 | sterling
# Processing Record 50 of Set 10 | paita
# Processing Record 1 of Set 11 | bestobe
# Processing Record 2 of Set 11 | russell
# Processing Record 3 of Set 11 | prescott
# Processing Record 4 of Set 11 | neiafu
# Processing Record 5 of Set 11 | fort-shevchenko
# Processing Record 6 of Set 11 | albuquerque
# Processing Record 7 of Set 11 | sur
# Processing Record 8 of Set 11 | marzuq
# Processing Record 9 of Set 11 | hede
# Processing Record 10 of Set 11 | yuanping
# Processing Record 11 of Set 11 | hami
# Processing Record 12 of Set 11 | surkhakhi
# Processing Record 13 of Set 11 | padang
# Processing Record 14 of Set 11 | cabinda
# Processing Record 15 of Set 11 | heze
# Processing Record 16 of Set 11 | blagoyevo
# Processing Record 17 of Set 11 | loiza
# Processing Record 18 of Set 11 | angatuba
# Processing Record 19 of Set 11 | saint-pierre
# Processing Record 20 of Set 11 | bahir dar
# Processing Record 21 of Set 11 | herat
# Processing Record 22 of Set 11 | wonthaggi
# Processing Record 23 of Set 11 | namanga
# Processing Record 24 of Set 11 | punta alta
# Processing Record 25 of Set 11 | berdigestyakh
# Processing Record 26 of Set 11 | lardos
# Processing Record 27 of Set 11 | haines junction
# Processing Record 28 of Set 11 | sorland
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | goderich
# Processing Record 31 of Set 11 | mayo
# Processing Record 32 of Set 11 | madingou
# Processing Record 33 of Set 11 | marquette
# Processing Record 34 of Set 11 | springdale
# Processing Record 35 of Set 11 | mahuva
# Processing Record 36 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 11 | pimenta bueno
# Processing Record 38 of Set 11 | alexandria
# Processing Record 39 of Set 11 | maravilha
# Processing Record 40 of Set 11 | hamilton
# Processing Record 41 of Set 11 | ostrovnoy
# Processing Record 42 of Set 11 | radishchevo
# Processing Record 43 of Set 11 | mwinilunga
# Processing Record 44 of Set 11 | fairbanks
# Processing Record 45 of Set 11 | vao
# Processing Record 46 of Set 11 | katsuura
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 11 | wanning
# Processing Record 50 of Set 11 | sitangkai
# Processing Record 1 of Set 12 | rupert
# Processing Record 2 of Set 12 | berlevag
# Processing Record 3 of Set 12 | krasnyy kholm
# Processing Record 4 of Set 12 | chifeng
# Processing Record 5 of Set 12 | sao joao da barra
# Processing Record 6 of Set 12 | mangai
# Processing Record 7 of Set 12 | la cruz
# Processing Record 8 of Set 12 | mezen
# Processing Record 9 of Set 12 | chenghai
# Processing Record 10 of Set 12 | sola
# Processing Record 11 of Set 12 | noyabrsk
# Processing Record 12 of Set 12 | yakeshi
# Processing Record 13 of Set 12 | yabrud
# Processing Record 14 of Set 12 | atherton
# Processing Record 15 of Set 12 | kurilsk
# Processing Record 16 of Set 12 | mancio lima
# Processing Record 17 of Set 12 | bell ville
# Processing Record 18 of Set 12 | jacala
# Processing Record 19 of Set 12 | golden
# Processing Record 20 of Set 12 | lekoni
# Processing Record 21 of Set 12 | ojinaga
# Processing Record 22 of Set 12 | margate
# Processing Record 23 of Set 12 | quelimane
# Processing Record 24 of Set 12 | mercedes
# Processing Record 25 of Set 12 | lorengau
# Processing Record 26 of Set 12 | kintampo
# Processing Record 27 of Set 12 | tateyama
# Processing Record 28 of Set 12 | homer
# Processing Record 29 of Set 12 | shingu
# Processing Record 30 of Set 12 | brooks
# Processing Record 31 of Set 12 | vestmanna
# Processing Record 32 of Set 12 | cabedelo
# Processing Record 33 of Set 12 | marawi
# Processing Record 34 of Set 12 | savelugu
# Processing Record 35 of Set 12 | longyearbyen
# Processing Record 36 of Set 12 | kolomna
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | riyadh
# Processing Record 39 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 12 | muriwai beach
# Processing Record 41 of Set 12 | magadan
# Processing Record 42 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 12 | phulpur
# Processing Record 44 of Set 12 | kimbe
# Processing Record 45 of Set 12 | chiang klang
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | poya
# Processing Record 48 of Set 12 | hofn
# Processing Record 49 of Set 12 | payo
# Processing Record 50 of Set 12 | kathmandu
# Processing Record 1 of Set 13 | olafsvik
# Processing Record 2 of Set 13 | zorritos
# Processing Record 3 of Set 13 | souillac
# Processing Record 4 of Set 13 | tuatapere
# Processing Record 5 of Set 13 | wukari
# Processing Record 6 of Set 13 | pedro carbo
# Processing Record 7 of Set 13 | gasa
# Processing Record 8 of Set 13 | oriximina
# Processing Record 9 of Set 13 | bantou
# Processing Record 10 of Set 13 | dire dawa
# Processing Record 11 of Set 13 | paamiut
# Processing Record 12 of Set 13 | lahat
# Processing Record 13 of Set 13 | teguise
# Processing Record 14 of Set 13 | pindiga
# Processing Record 15 of Set 13 | oksovskiy
# Processing Record 16 of Set 13 | humberto de campos
# Processing Record 17 of Set 13 | san joaquin
# Processing Record 18 of Set 13 | jaque
# Processing Record 19 of Set 13 | seymchan
# Processing Record 20 of Set 13 | pedernales
# Processing Record 21 of Set 13 | belle fourche
# Processing Record 22 of Set 13 | mitu
# Processing Record 23 of Set 13 | lianran
# Processing Record 24 of Set 13 | dromolaxia
# Processing Record 25 of Set 13 | ukiah
# Processing Record 26 of Set 13 | road town
# Processing Record 27 of Set 13 | sao gabriel da cachoeira
# Processing Record 28 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 13 | tezu
# Processing Record 30 of Set 13 | surt
# Processing Record 31 of Set 13 | coronado
# Processing Record 32 of Set 13 | acarau
# Processing Record 33 of Set 13 | guaymas
# Processing Record 34 of Set 13 | acari
# Processing Record 35 of Set 13 | avera
# Processing Record 36 of Set 13 | duliagaon
# Processing Record 37 of Set 13 | hare bay
# Processing Record 38 of Set 13 | luohe
# Processing Record 39 of Set 13 | marsh harbour
# Processing Record 40 of Set 13 | saurimo
# Processing Record 41 of Set 13 | mandan
# Processing Record 42 of Set 13 | makakilo city
# Processing Record 43 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 13 | menongue
# Processing Record 45 of Set 13 | beboto
# Processing Record 46 of Set 13 | massaguet
# Processing Record 47 of Set 13 | eunice
# Processing Record 48 of Set 13 | bage
# Processing Record 49 of Set 13 | jaicos
# Processing Record 50 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 14 | gawler
# Processing Record 2 of Set 14 | evensk
# Processing Record 3 of Set 14 | verkhoyansk
# Processing Record 4 of Set 14 | winslow
# Processing Record 5 of Set 14 | nagato
# Processing Record 6 of Set 14 | nuwara eliya
# Processing Record 7 of Set 14 | natchitoches
# Processing Record 8 of Set 14 | cumpas
# Processing Record 9 of Set 14 | belaya gora
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | shimoda
# Processing Record 12 of Set 14 | honningsvag
# Processing Record 13 of Set 14 | lakes entrance
# Processing Record 14 of Set 14 | kazan
# Processing Record 15 of Set 14 | escanaba
# Processing Record 16 of Set 14 | ciudad bolivar
# Processing Record 17 of Set 14 | plouzane
# Processing Record 18 of Set 14 | chicholi
# Processing Record 19 of Set 14 | mestia
# Processing Record 20 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 21 of Set 14 | severnoye
# Processing Record 22 of Set 14 | egvekinot
# Processing Record 23 of Set 14 | belmonte
# Processing Record 24 of Set 14 | abu samrah
# Processing Record 25 of Set 14 | yangambi
# Processing Record 26 of Set 14 | octeville
# Processing Record 27 of Set 14 | kalachinsk
# Processing Record 28 of Set 14 | vung tau
# Processing Record 29 of Set 14 | chapais
# Processing Record 30 of Set 14 | brae
# Processing Record 31 of Set 14 | akhnur
# Processing Record 32 of Set 14 | kidal
# Processing Record 33 of Set 14 | erechim
# Processing Record 34 of Set 14 | felanitx
# Processing Record 35 of Set 14 | uglekamensk
# Processing Record 36 of Set 14 | la romana
# Processing Record 37 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 14 | teguldet
# Processing Record 39 of Set 14 | don benito
# Processing Record 40 of Set 14 | suicheng
# Processing Record 41 of Set 14 | kirakira
# Processing Record 42 of Set 14 | sibolga
# Processing Record 43 of Set 14 | atar
# Processing Record 44 of Set 14 | pekan
# Processing Record 45 of Set 14 | vostok
# Processing Record 46 of Set 14 | msanga
# Processing Record 47 of Set 14 | sabang
# Processing Record 48 of Set 14 | taoudenni
# Processing Record 49 of Set 14 | iaciara
# Processing Record 50 of Set 14 | parabel
# Processing Record 1 of Set 15 | aureliana
# Processing Record 2 of Set 15 | antalaha
# Processing Record 3 of Set 15 | puerto narino
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | goure
# Processing Record 6 of Set 15 | nemuro
# Processing Record 7 of Set 15 | visnes
# Processing Record 8 of Set 15 | iqaluit
# Processing Record 9 of Set 15 | pucallpa
# Processing Record 10 of Set 15 | george
# Processing Record 11 of Set 15 | gushikawa
# Processing Record 12 of Set 15 | dauriya
# Processing Record 13 of Set 15 | harnosand
# Processing Record 14 of Set 15 | shirpur
# Processing Record 15 of Set 15 | torbay
# Processing Record 16 of Set 15 | tiznit
# Processing Record 17 of Set 15 | mount pleasant
# Processing Record 18 of Set 15 | peterhead
# Processing Record 19 of Set 15 | zacapoaxtla
# Processing Record 20 of Set 15 | tsabong
# Processing Record 21 of Set 15 | kiama
# Processing Record 22 of Set 15 | yandyki
# Processing Record 23 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 15 | griffith
# Processing Record 26 of Set 15 | perelyub
# Processing Record 27 of Set 15 | najran
# Processing Record 28 of Set 15 | maltahohe
# Processing Record 29 of Set 15 | dingle
# Processing Record 30 of Set 15 | kawalu
# Processing Record 31 of Set 15 | tiszakeszi
# Processing Record 32 of Set 15 | port hedland
# Processing Record 33 of Set 15 | tombouctou
# Processing Record 34 of Set 15 | biak
# Processing Record 35 of Set 15 | viet tri
# Processing Record 36 of Set 15 | hambantota
# Processing Record 37 of Set 15 | pangnirtung
# Processing Record 38 of Set 15 | troitsko-pechorsk
# Processing Record 39 of Set 15 | kirkwall
# Processing Record 40 of Set 15 | porto walter
# Processing Record 41 of Set 15 | batesville
# Processing Record 42 of Set 15 | barrancabermeja
# Processing Record 43 of Set 15 | indramayu
# Processing Record 44 of Set 15 | ravar
# Processing Record 45 of Set 15 | paramonga
# Processing Record 46 of Set 15 | tiruvallur
# Processing Record 47 of Set 15 | sao filipe
# Processing Record 48 of Set 15 | rosarito
# Processing Record 49 of Set 15 | larsnes
# Processing Record 50 of Set 15 | talara
# Processing Record 1 of Set 16 | ranau
# Processing Record 2 of Set 16 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 3 of Set 16 | lingyuan
# Processing Record 4 of Set 16 | surin
# Processing Record 5 of Set 16 | uniontown
# Processing Record 6 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 16 | atbasar
# Processing Record 8 of Set 16 | mayor pablo lagerenza
# Processing Record 9 of Set 16 | ushumun
# Processing Record 10 of Set 16 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 16 | garachine
# Processing Record 12 of Set 16 | ust-tsilma
# Processing Record 13 of Set 16 | ratnagiri
# Processing Record 14 of Set 16 | nizwa
# Processing Record 15 of Set 16 | camacha
# Processing Record 16 of Set 16 | sorkjosen
# Processing Record 17 of Set 16 | lethem
# Processing Record 18 of Set 16 | opotiki
# Processing Record 19 of Set 16 | velsk
# Processing Record 20 of Set 16 | nykobing
# City not found. Skipping...
# Processing Record 21 of Set 16 | kousseri
# Processing Record 22 of Set 16 | dolores
# Processing Record 23 of Set 16 | komsomolskiy
# Processing Record 24 of Set 16 | banjar
# Processing Record 25 of Set 16 | cabadiangan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Busselton      AU -33.6500  115.3333     63.91        65
# 1                Tubigan      PH   8.5322  124.3122     78.98        83
# 2               Thompson      CA  55.7435  -97.8558     24.96        80
# 3                Mataura      NZ -46.1927  168.8643     54.64        56
# 4  Los Llanos De Aridane      ES  28.6585  -17.9182     64.15        64
# 5               Ust-Nera      RU  64.5667  143.2000    -12.41        98
# 6         Cabo San Lucas      MX  22.8909 -109.9124     77.31        69
# 7                  Airai      TL  -8.9266  125.4092     61.61        91
# 8           Punta Arenas      CL -53.1500  -70.9167     59.11        38
# 9                 Albany      US  42.6001  -73.9662     32.65        62
#
#    Cloudiness  Wind Speed Current Description
# 0           0        5.41           clear sky
# 1          84        4.27       broken clouds
# 2          90       17.27          light snow
# 3          76        1.97       broken clouds
# 4          40       21.85    scattered clouds
# 5         100        7.47     overcast clouds
# 6          90        5.75     overcast clouds
# 7          98        1.63     overcast clouds
# 8          75       14.97       broken clouds
# 9           8       12.35           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
